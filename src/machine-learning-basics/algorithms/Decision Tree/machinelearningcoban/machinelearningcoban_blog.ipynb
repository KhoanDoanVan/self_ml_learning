# %% [markdown]
# # Decision Tree algorithm

# %% [markdown]
# Decision Tree là thuật toán supervised learning, có thể giải quyết cả bài toán regression và classification.

# %% [markdown]
# ## Giới thiệu về thuật toán Decision Tree

# %% [markdown]
# Một thuật toán Machine Learning thường sẽ có 2 bước:
#
# 1. Huấn luyện: Từ dữ liệu thuật toán sẽ học ra model.
# 2. Dự đoán: Dùng model học được từ bước trên dự đoán các giá trị mới.

# %% [markdown]
# Bước huấn luyện ở thuật toán Decision Tree sẽ xây dựng ra một cây quyết định. Ví dụ, như với dữ liệu Titatic, thuật toán Decision Tree sẽ học ra model dạng cây như thế này

# %% [markdown]
# ![](image1.png)

# %% [markdown]
# Thông tin Title được lấy ra từ trường Name. Sau đó trường Title, Sex được chuyển về dạng số

# %%
title_mapping   = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
sex_mapping     = {'female': 0, 'male': 1}

# %% [markdown]
# Sau đó ở bước dự đoán, thuật toán sẽ dựa vào thông tin của hành khách và đi theo các điều kiện của cây từ trên xuống dưới để cho ra dự đoán xem người đó sống hay chết. Ví dụ với thông tin khách hàng thế này:

# %%
import pandas as pd
titanic_path = "https://media.githubusercontent.com/media/tiepvupsu/tabml_data/master/titanic/"
data = pd.read_csv(titanic_path + "train.csv")
data.head(1)

# %% [markdown]
# Từ trường Name, mình sẽ lấy được Title là “Mr” rồi chuyển về dạng số là 1.
#
# 1. Title = 1 <= 1.5, điều kiện đúng nên kiểm tra tiếp điều kiện ở node con phía dưới bên trái.
# 2. Has_Cabin = 0 <= 0.5, điều kiện đúng nên kiểm tra tiếp điều kiện ở node con ở dưới bên trái (trường Cabin là NaN nên has_cabin thành 0).
# 3. Pclass = 3 >= 1.5, điều kiện sai nên xuống node con bên phải, node này là node lá có kết quả dự đoán luôn chứ không cần kiểm tra điều kiện nữa.
# 4. Lấy thông tin từ node lá, dự đoán class = Died.

# %% [markdown]
# ![](image2.png)

# %% [markdown]
# Ở cây quyết định này mình thấy 2 kiểu node:
# 1. Node có điều kiện kiểm tra, mình gọi là node điều kiện. Các node điều kiện đều có 2 node con ở dưới.
# 2. Node lá, không có điều kiện mà có kết quả dự đoán. Các node lá không có node con.

# %% [markdown]
# Bây giờ thì mình biết có cây quyết định thì sẽ dự đoán 1 giá trị mới như thế nào rồi. Vấn đề bây giờ là làm thế nào để xây dựng cây quyết định.

# %% [markdown]
# ## Xây dựng cây quyết định

# %% [markdown]
# Bài toán là giờ mình có dữ liệu, làm thế nào để xây dựng ra cây quyết định.

# %% [markdown]
# Giả sử mình có bài toán phân loại 2 lớp và mỗi dữ liệu có 2 thuộc tính là $x_1$ và $x_2$. Dữ liệu của mình khi vẽ biểu đồ scatter lên sẽ như thế này.

# %% [markdown]
# ![](image3.png)

# %% [markdown]
# Với dữ liệu này, nếu yêu cầu mọi người dùng giấy bút vẽ cây quyết định mọi người sẽ làm thế nào?

# %% [markdown]
# Xét điều kiện $𝑥_1 > 5$, giống như một đường phân chia, chia dữ liệu làm 2 phần, 1 phần thỏa mãn điều kiện và 1 phần không thỏa mãn điều kiện.

# %% [markdown]
# ![](image4.png)

# %% [markdown]
# Mình thấy nếu $x_1>5$ đúng thì tất cả các dữ liệu thuộc lớp 1, thế nên mình sẽ dùng lớp lá để dự đoán đây là lớp 1 luôn. Ngược lại thì mình thấy dữ liệu có cả lớp 1 và lớp 0, nên mình tiếp tục thêm điều kiện $𝑥_2>4$

# %% [markdown]
# ![](image5.png)

# %% [markdown]
# Nếu điều kiện $𝑥_2>4$ đúng thì mình thấy các dữ liệu thuộc lớp 1, ngược lại các dữ liệu thuộc lớp 0. Do đó 2 node con của node điều kiện trên đều là node lá để cho ra kết quả dự đoán.

# %% [markdown]
# Cuối cùng mình sẽ được cây quyết định như thế này.

# %% [markdown]
# ![](image6.png)

# %% [markdown]
# Vậy tiêu chí gì để mình tìm được điều kiện đầu tiên? tại sao lại là $𝑥_1$ và tại sao lại là 5 mà không phải là một số khác? Nếu mọi người để ý ở trên thì mình sẽ tạo điều kiện để tách dữ liệu thành 2 phần mà dữ liệu mỗi phần có tính phân tách hơn dữ liệu ban đầu.

# %% [markdown]
# Ví dụ: điều kiện $x_1>5$, tại nhánh đúng thì tất cả các phần tử đều thuộc lớp 1.

# %% [markdown]
# - Thế điều kiện $𝑥_1>8$ cũng chia nhánh đúng thành toàn lớp 1 sao không chọn?
#     - vì nhánh đúng ở điều kiện $𝑥_1>5$ chứa nhiều phần tử lớp 1 hơn và tổng quát hơn nhán đúng của $𝑥_1>8$
# - Còn điều kiện $𝑥_1>2$ thì cả 2 nhánh con đều chứa dữ liệu của cả lớp 0 và lớp 1.

# %% [markdown]
# Mình biết tiêu chí để chọn rồi, nhưng tiêu chí mình vừa đề ra dựa vào mắt và cảm quan, máy tính thì cần số liệu để đánh giá để so sánh các điều kiện phân tách. Các chỉ số để đánh giá ra đời, bao gồm: $\text{entropy}$, $\text{information gain}$.

# %% [markdown]
# Với mỗi điều kiện để tách thì sẽ có chỉ số information gain tương ứng, chỉ số information gain càng cao thì việc tách càng tốt.

# %% [markdown]
# Do đó mình sẽ duyệt qua hết các thuộc tính của dữ liệu, mỗi thuộc tính thử các giá trị để tách khác nhau, rồi chọn điều kiện có chỉ số information gain cao nhất để tách, và tiếp tục như thế cho tới node lá, chỉ gồm dữ liệu 1 lớp duy nhất.

# %% [markdown]
# Chi tiết về thuật toán $\text{ID3}$, $\text{entropy}$, $\text{information gain}$ được viết ở blog Machine Learning cơ bản

# %% [markdown]
# Ngoài $\text{ID3}$ còn có các thuật toán khác cho $\text{Decision Tree}$ như:
# - $\text{C4.5}$: Successor of ID3
# - $\text{CART}$: Classification And Regression Tree
# - $\text{CHAID}$: Chi-square automatic interaction detection Performs multi-level splits when computing classification trees
# - $\text{MARS}$: multivariate adaptive regression splines

# %% [markdown]
# Phần dưới mình sẽ trình bày về $\text{gini index}$ (chỉ số đánh giá được sử dụng trong thuật toán CART).

# %% [markdown]
# ## GINI INDEX

# %% [markdown]
# Gini index tương tự như information gain, dùng để đánh giá xem việc phân chia ở node điều kiện có tốt hay không.

# %% [markdown]
# Để tính Gini index, trước hết mình sẽ tính chỉ số Gini, chỉ số Gini tính ở từng node.

# %% [markdown]
# $$
# Gini = 1 - \sum_{i=1}^{C}(p_i)^2
# $$

# %% [markdown]
# Trong đó:
# - $C$ là số lớp cần phân loại
# - $p_i = \frac{n_i}{N}$
#     - $n_i$ là số lượng phần tử ở lớp thứ $i$
#     - $N$ là tổng số lượng phần tử ở node đó, $N = \sum_{i=1}^{N}{n_i} \rightarrow \sum_{i=1}^{N}{p_i} = 1$

# %% [markdown]
# Do $0 \leq p_i \leq 1 \space ∀i$ và $\sum_{i=1}^{N}{p_i} = 1$ nên:

# %% [markdown]
# ![](image7.png)

# %% [markdown]
# Mọi người thấy:
# - Ở node $𝑥_1>5$ thì có tất cả 20 điểm dữ liệu, gồm 5 điểm lớp 0 và 15 điểm lớp 1, gini = 0.375.
# - Ở node lá ở dưới, tất cả dữ liệu thuộc lớp 1 nên gini = 0.

# %% [markdown]
# $\rightarrow$ Chỉ số gini thấp nhất (=0) khi node đó chỉ chứa dữ liệu của 1 lớp duy nhất, chỉ số gini cao nhất khi dữ liệu các lớp ở trong node đó cân bằng (đã chứng minh ở trên) => Ta mong muốn khi phân tách thì chỉ số gini ở những lớp con thấp.

# %% [markdown]
# Sau khi tính được chỉ số gini ở node cha và 2 node con được tính, ta tính được chỉ số gini index:
#
# $$
# gini\_index = gini(p) - \sum_{i=1}^{K}{\frac{m_k}{M}gini(c_k)}
# $$

# %% [markdown]
# Trong đó:
# - $𝑔𝑖𝑛𝑖(𝑝)$ là chỉ số gini ở node cha
# - $K$ là số node con được tách ra
# - $gini(c_k)$ là chi số gini ở node con thứ $k$
# - $M$ là số phần tử ở node $p$
# - $m_i$ là số phần tử ở node con thứ $i$

# %% [markdown]
# Thực ra gini index tính độ lệch gini của node cha với tổng các giá trị gini có đánh trọng số của các node con.

# %% [markdown]
# Như ở ví dụ mình ở trên thì:
#
# $$
# gini\_index = 0.375 - (\frac{10}{20} \times 0 + \frac{10}{20} \times 0.5) = 0.125
# $$

# %% [markdown]
# Vì khi tách mình muốn chỉ số gini ở các node con nhỏ, nên gini index mình mong muốn càng lớn càng tốt.

# %% [markdown]
# Thuật toán $\text{CART}$ khá giống $\text{ID3}$, chỉ thay gini index bằng $\text{information gain}$.

# %% [markdown]
# Để tìm điều kiện tách, mình thử ở tất các thuộc tính, mỗi thuộc tính thử một số giá trị chia, rồi so sánh xem điều kiện nào chỉ số gini index giảm nhiều nhất thì sẽ chọn để chia.

# %% [markdown]
# Thực ra, kết quả dùng với gini index hay information gain khá giống nhau, có chăng thì gini index dễ tính hơn vì không phải tính log, chi tiết so sánh mọi người xem ở đây.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# Các thuật toán Decision Tree nói chung nếu xây dựng cây quyết định đủ sâu thì sẽ tách được các node lá chỉ chứa dữ liệu một lớp nhất định, nên mô hình rất dễ bị overfitting.

# %% [markdown]
# ![](image8.png)

# %% [markdown]
# Mọi người thấy mô hình Decision Tree trên overfitting với dữ liệu, và tạo ra đường phân chia rất lạ. Thường có 2 cách giải quyết khi model Decision Tree bị overfitting:
#
# 1. Dừng việc thêm các node điều kiện vào cây dựa vào các điều kiện:
# - Giới hạn độ sâu của cây.
# - Chỉ định số phần tử tối thiểu (n) trong node lá, nếu 1 node có số phần tử ít hơn n thì sẽ không tách nữa.
#
# 2. Pruning.

# %% [markdown]
# Phần sau mình sẽ học thuật toán Random Forest được xây dựng từ thuật toán Decision Tree và tránh được overfitting.

# %% [markdown]
# Ví dụ mô hình trên khi mình giới hạn độ sâu của cây là 5 và số phần tử tối thiểu trong lớp lá là 5. Mọi người thấy mô hình đỡ bị overfitting hơn, và đường phân chia tổng quát dữ liệu hơn.

# %% [markdown]
# ![](image9.png)

# %% [markdown]
# ## Các node trong hình cây quyết định sinh ra bởi dữ liệu Titanic

# %% [markdown]
# ![](image10.png)

# %% [markdown]
# 1. Đầu tiên là điều kiện để tách.
# 2. Sau đó là chỉ số gini ở node nó.
# 3. Tổng số dữ liệu ở node đó.
# 4. Số lượng dữ liệu là Died và Survived, lần lượt là 113 và 261, nhận xét: 113 + 261 = 374 (tổng số sample).
# 5. Dự đoán ở node này, nếu cần. Do 261 > 113 => dự đoán là Survived.

# %% [markdown]
# ![](image11.png)

# %% [markdown]
# Số dữ liệu ở node cha bằng tổng số dữ liệu ở 2 node con, 517 + 374 = 891.
