# %% [markdown]
# # How does convolution/pooling apply to audio?

# %% [markdown]
# - Spectrogram/MFCC = image
# - Time, frequency = x, y
# - Amplitude = pixel value

# %% [markdown]
# # Preparing MFCCs for a CNN

# %% [markdown]
# - 13 MFCCs
# - Hop Length = 512 samples
# - Samples in audio file = 51200

# %% [markdown]
# Data Shape = $100 \times 13 \times 1$

# %% [markdown]
# ![](image1.png)
